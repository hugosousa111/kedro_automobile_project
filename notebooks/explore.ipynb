# %%
catalog.list()
# Out:
# [
#     'MLPredictor',
#     'raw_dataset',
#     'pp_dataset',
#     'dataset_expanded',
#     'oe_transformer',
#     'regressor',
#     'regressor_metrics',
#     'parameters',
#     'params:test_size',
#     'params:random_state'
# ]

# %%
df = catalog.load('raw_dataset')
# Out:
# [11/07/22 10:33:00] INFO     Loading data from 'raw_dataset' (CSVDataSet)...                    data_catalog.py:343

# %%
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>symboling</th>
#       <th>normalized-losses</th>
#       <th>make</th>
#       <th>fuel-type</th>
#       <th>aspiration</th>
#       <th>num-of-doors</th>
#       <th>body-style</th>
#       <th>drive-wheels</th>
#       <th>engine-location</th>
#       <th>wheel-base</th>
#       <th>...</th>
#       <th>engine-size</th>
#       <th>fuel-system</th>
#       <th>bore</th>
#       <th>stroke</th>
#       <th>compression-ratio</th>
#       <th>horsepower</th>
#       <th>peak-rpm</th>
#       <th>city-mpg</th>
#       <th>highway-mpg</th>
#       <th>price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  164 non-null    float64
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       203 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
# %reload_kedro
# Out:
# [10/20/22 13:39:52] INFO     No path argument was provided. Using: /home/hugo/Área de                __init__.py:56
#                              Trabalho/Indicium/Lighthouse/automobile_project/automobile-project
# [10/20/22 13:39:52] INFO     Kedro project automobile_project                                        __init__.py:77
#                     INFO     Defined global variable 'context', 'session', 'catalog' and 'pipelines' __init__.py:78

# %%
df.shape
# Out:
# (205, 26)

# %%
df.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
df=df.drop(columns=['normalized-losses'])
df.shape
# Out:
# (205, 25)

# %%
df.isnull().sum()
# Out:
# symboling            0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 4
# stroke               4
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                4
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 193 entries, 0 to 204
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          193 non-null    int64
#  1   make               193 non-null    object
#  2   fuel-type          193 non-null    object
#  3   aspiration         193 non-null    object
#  4   num-of-doors       193 non-null    object
#  5   body-style         193 non-null    object
#  6   drive-wheels       193 non-null    object
#  7   engine-location    193 non-null    object
#  8   wheel-base         193 non-null    float64
#  9   length             193 non-null    float64
#  10  width              193 non-null    float64
#  11  height             193 non-null    float64
#  12  curb-weight        193 non-null    int64
#  13  engine-type        193 non-null    object
#  14  num-of-cylinders   193 non-null    object
#  15  engine-size        193 non-null    int64
# ...

# %%
df['fuel-system'].unique()
# Out:
# array(['mpfi', '2bbl', 'mfi', '1bbl', 'spfi', 'idi', 'spdi'], dtype=object)

# %%
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>symboling</th>
#       <th>make</th>
#       <th>fuel-type</th>
#       <th>aspiration</th>
#       <th>num-of-doors</th>
#       <th>body-style</th>
#       <th>drive-wheels</th>
#       <th>engine-location</th>
#       <th>wheel-base</th>
#       <th>length</th>
#       <th>...</th>
#       <th>engine-size</th>
#       <th>fuel-system</th>
#       <th>bore</th>
#       <th>stroke</th>
#       <th>compression-ratio</th>
#       <th>horsepower</th>
#       <th>peak-rpm</th>
#       <th>city-mpg</th>
#       <th>highway-mpg</th>
#       <th>price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
def pre_processing(df):
    df=df.drop(columns=['normalized-losses'])
    df.dropna(inplace=True)
    return df

# %%
df['engine-type']
# Out:
# 0      dohc
# 1      dohc
# 2      ohcv
# 3       ohc
# 4       ohc
#        ...
# 200     ohc
# 201     ohc
# 202    ohcv
# 203     ohc
# 204     ohc
# Name: engine-type, Length: 193, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 193 entries, 0 to 204
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          193 non-null    int64
#  1   make               193 non-null    object
#  2   fuel-type          193 non-null    object
#  3   aspiration         193 non-null    object
#  4   num-of-doors       193 non-null    object
#  5   body-style         193 non-null    object
#  6   drive-wheels       193 non-null    object
#  7   engine-location    193 non-null    object
#  8   wheel-base         193 non-null    float64
#  9   length             193 non-null    float64
#  10  width              193 non-null    float64
#  11  height             193 non-null    float64
#  12  curb-weight        193 non-null    int64
#  13  engine-type        193 non-null    object
#  14  num-of-cylinders   193 non-null    object
#  15  engine-size        193 non-null    int64
# ...

# %%
columns_to_transform = [
    'make', 'fuel-type', 
    'aspiration', 'num-of-doors', 
    'body-style', 'drive-wheels', 
    'engine-location', 'engine-type',
    'num-of-cylinders', 'fuel-system']

# %%
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>symboling</th>
#       <th>make</th>
#       <th>fuel-type</th>
#       <th>aspiration</th>
#       <th>num-of-doors</th>
#       <th>body-style</th>
#       <th>drive-wheels</th>
#       <th>engine-location</th>
#       <th>wheel-base</th>
#       <th>length</th>
#       <th>...</th>
#       <th>engine-size</th>
#       <th>fuel-system</th>
#       <th>bore</th>
#       <th>stroke</th>
#       <th>compression-ratio</th>
#       <th>horsepower</th>
#       <th>peak-rpm</th>
#       <th>city-mpg</th>
#       <th>highway-mpg</th>
#       <th>price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder
from sklearn.compose import make_column_transformer
from seaborn import load_dataset
import pandas as pd

oe = OrdinalEncoder()
df[columns_to_transform] = oe.fit_transform(df[columns_to_transform])

# %%
type(oe)
# Out:
# <class 'sklearn.preprocessing._encoders.OrdinalEncoder'>

# %%
df[columns_to_transform] = oe.inverse_transform(df[columns_to_transform])

# %%
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>symboling</th>
#       <th>make</th>
#       <th>fuel-type</th>
#       <th>aspiration</th>
#       <th>num-of-doors</th>
#       <th>body-style</th>
#       <th>drive-wheels</th>
#       <th>engine-location</th>
#       <th>wheel-base</th>
#       <th>length</th>
#       <th>...</th>
#       <th>engine-size</th>
#       <th>fuel-system</th>
#       <th>bore</th>
#       <th>stroke</th>
#       <th>compression-ratio</th>
#       <th>horsepower</th>
#       <th>peak-rpm</th>
#       <th>city-mpg</th>
#       <th>highway-mpg</th>
#       <th>price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
def one_hot_encoder_str_columns(df):
    transformer = make_column_transformer(
        (OneHotEncoder(), columns_to_transform),
        remainder='passthrough'
    )

    transformed = transformer.fit_transform(df)
    df = pd.DataFrame(transformed, columns=transformer.get_feature_names_out())
    return df, transformer


# Inverse the encoded
fit.apply(lambda x: d[x.name].inverse_transform(x))

# Using the dictionary to label future data
df.apply(lambda x: d[x.name].transform(x))

# %%
df, transformer = one_hot_encoder_str_columns(df)

# %%
X = df.drop('price', axis = 1)
y = df['price']
"""
int_columns = [
    'symboling', 'wheel-base', 'length', 
    'width', 'height', 'curb-weight', 
    'engine-size', 'bore', 'stroke',
    'compression-ratio', 'horsepower', 
    'peak-rpm', 'city-mpg', 'highway-mpg']
X = X[int_columns]
"""
# Out:
# "\nint_columns = [\n    'symboling', 'wheel-base', 'length', \n    'width', 'height', 'curb-weight', \n    'engine-size', 'bore', 'stroke',\n    'compression-ratio', 'horsepower', \n    'peak-rpm', 'city-mpg', 'highway-mpg']\nX = X[int_columns]\n"

# %%
X
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>symboling</th>
#       <th>make</th>
#       <th>fuel-type</th>
#       <th>aspiration</th>
#       <th>num-of-doors</th>
#       <th>body-style</th>
#       <th>drive-wheels</th>
#       <th>engine-location</th>
#       <th>wheel-base</th>
#       <th>length</th>
#       <th>...</th>
#       <th>num-of-cylinders</th>
#       <th>engine-size</th>
#       <th>fuel-system</th>
#       <th>bore</th>
#       <th>stroke</th>
#       <th>compression-ratio</th>
#       <th>horsepower</th>
#       <th>peak-rpm</th>
#       <th>city-mpg</th>
#       <th>highway-mpg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.1, random_state=42
)

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 49 to 77
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          20 non-null     int64
#  1   make               20 non-null     int64
#  2   fuel-type          20 non-null     int64
#  3   aspiration         20 non-null     int64
#  4   num-of-doors       20 non-null     int64
#  5   body-style         20 non-null     int64
#  6   drive-wheels       20 non-null     int64
#  7   engine-location    20 non-null     int64
#  8   wheel-base         20 non-null     float64
#  9   length             20 non-null     float64
#  10  width              20 non-null     float64
#  11  height             20 non-null     float64
#  12  curb-weight        20 non-null     int64
#  13  engine-type        20 non-null     int64
#  14  num-of-cylinders   20 non-null     int64
#  15  engine-size        20 non-null     int64
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# Training and Testing the model
regressor = LinearRegression()

regressor.fit(X_train,y_train)

y_pred = regressor.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8424666380684674

# %%
X_train
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>symboling</th>
#       <th>make</th>
#       <th>fuel-type</th>
#       <th>aspiration</th>
#       <th>num-of-doors</th>
#       <th>body-style</th>
#       <th>drive-wheels</th>
#       <th>engine-location</th>
#       <th>wheel-base</th>
#       <th>length</th>
#       <th>...</th>
#       <th>num-of-cylinders</th>
#       <th>engine-size</th>
#       <th>fuel-system</th>
#       <th>bore</th>
#       <th>stroke</th>
#       <th>compression-ratio</th>
#       <th>horsepower</th>
#       <th>peak-rpm</th>
#       <th>city-mpg</th>
#       <th>highway-mpg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
y_test
# Out:
# 45     36000.0
# 137    11694.0
# 76      6989.0
# 144     6938.0
# 113     7609.0
# 152     8238.0
# 15     41315.0
# 18      6295.0
# 16     36880.0
# 9      16430.0
# 78      9279.0
# 112     6692.0
# 66     16503.0
# 65     45400.0
# 154     9538.0
# 30      5399.0
# 146     7898.0
# 69      6669.0
# 111     6229.0
# 68      6189.0
# 158    11199.0
# 135    10198.0
# 118    34028.0
# 98     11900.0
# 67      5389.0
# 115    12764.0
# 24      6692.0
# 159    11549.0
# 60     28176.0
# 142     7898.0
# 114     8921.0
# 167    15998.0
# 19      6575.0
# 90      8949.0
# 171     7975.0
# 5      15250.0
# 155     8449.0
# 143     8778.0
# 166    16558.0
# 82      6649.0
# 109     5572.0
# 163     9988.0
# 35      7895.0
# 136     8013.0
# 42     11048.0
# 183    13415.0
# 101    13860.0
# 55     11245.0
# 75     14489.0
# 126     5118.0
# 29      6855.0
# 172     7995.0
# 56     18280.0
# 51      8845.0
# 164    10898.0
# 38     10295.0
# 31      6529.0
# 156     9639.0
# ...

# %%
type(regressor)
# Out:
# <class 'sklearn.linear_model._base.LinearRegression'>
